# %% [markdown]
# # 1.1 - Imports

# %%
import matplotlib.pyplot as plt
from collections import Counter
from typing import List, Tuple, Any, Iterable
import torch
from torchvision import datasets, transforms
import sys
import os
sys.path.append("../src")
from visualization import show_one_image_per_label, plot_data_distribution
from data_utils import load_mnist_data

# %% [markdown]
# # 1.2 - Charger les datasets via data_utils

# %%
labeled_loader, unlabeled_loader, test_loader = load_mnist_data(
    data_dir="../data",
    labeled_fraction=0.1,
    batch_size=64
)

# %% [markdown]
# # 1.3 - Accès direct à des datasets pour visualisation

# %%
train_dataset=labeled_loader.dataset
test_dataset=unlabeled_loader.dataset

# %% [markdown]
# # 1.5 - Une image par chiffre

# %%
show_one_image_per_label(train_dataset)

# %% [markdown]
# # 1.6 - Répartition des classes (train et test)

# %%
plot_data_distribution(train_dataset, title="Répartition des classes (Train)")
plot_data_distribution(test_dataset, title="Répartition des classes (Test)")
